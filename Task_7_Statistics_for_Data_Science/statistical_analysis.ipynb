# %% [markdown]
# # Statistical Business Analysis
#
# This notebook companion uses the actual Week 7 sales and customer churn datasets.

# %%
import pandas as pd
from scipy import stats
sales = pd.read_csv('sales_data.csv')
customers = pd.read_csv('customer_churn.csv')
sales['Date'] = pd.to_datetime(sales['Date'])
sales.describe()

# %%
stats.ttest_1samp(sales['Total_Sales'], 100000)
