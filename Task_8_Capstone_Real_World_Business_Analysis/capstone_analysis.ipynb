# %% [markdown]
# # Week 8 Capstone - Real World Business Analysis
#
# Business problem: use actual sales, churn, and property data to identify actionable performance opportunities.

# %%
import pandas as pd
from pathlib import Path
root = Path('.') / 'data'
house = pd.read_csv(root / 'house_prices.csv')
churn = pd.read_csv(root / 'customer_churn.csv')
sales = pd.read_csv(root / 'sales_data.csv')
sales['Date'] = pd.to_datetime(sales['Date'])
house.shape, churn.shape, sales.shape

# %% [markdown]
# ## Data Cleaning and EDA
# Validate missing values, duplicates, data types, and business ranges before analysis.

# %%
print(house.describe())
print(churn.groupby('Contract')['Churn'].mean())
print(sales.groupby('Product')['Total_Sales'].sum())

# %% [markdown]
# ## Statistical Analysis and Visualizations
# The reproducible Python script generates the complete charts, reports, and presentation.
