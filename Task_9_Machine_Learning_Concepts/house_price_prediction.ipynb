# %% [markdown]
# # Week 9 - House Price Prediction
#
# This notebook follows the same reproducible workflow as `house_price_prediction.py`.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
data = pd.read_csv('data/house_prices.csv')
data.info()
data.describe()

# %% [markdown]
# ## Data Cleaning and Feature Preparation
#
# Location and Property_Type are one-hot encoded. Price is the target.

# %%
features = pd.get_dummies(data[['Area','Bedrooms','Bathrooms','Age','Location','Property_Type']], dtype=float)
target = data['Price']
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
x_train.shape, x_test.shape

# %% [markdown]
# ## Regression, Evaluation, and Visualizations
#
# The Python script contains the complete scratch normal-equation implementation, scikit-learn model, metrics, and saved charts.
